# %% [markdown]
# <div style="width:100%;border-collapse:separate;border:solid 2px;border-radius:14px;border-color:pink">
#     <div style="display:flex;">
#         <div style="display:inline;width:20%;text-align:left;padding-left: 10px;"><b>Pablo Neruda</b></div>
#         <div style="display:inline;width:60%;text-align:center"></div>
#         <div style="display:inline;width:20%;text-align:right;padding-right: 10px;"><b> 1 NSI</b></div>
#     </div>
#     <div  style="display: flex;background-color:#EEE"> <img src="https://megamaths.hd.free.fr/static/logo_NSI_Pablo.svg" width="50px" style="float:left;  vertical-align: bottom;" >
#         <h1 style="width:100%;text-align:center; ">Les bases de Python</h1>
#     </div>
#     <div  style="display: flex;">
#          <div style="display:inline;width:20%;text-align:left;padding-left: 10px;">&#160; </div>
#         <div style="display:inline;width:60%;text-align:center">&#160; </div>
#         <div style="display:inline;width:20%;text-align:right;padding-right: 10px;">&#160;</div>
#     </div>
#     </div>

# %% [markdown]
# <p>Document  sous licence CC BY-NC-SA 4.0 ! <img alt="CC BY-NC-SA 4.0" src='https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-nc.eu.svg'  width=80px style="display:inline" /></p>

# %% [markdown]
# !!! abstract  Mode d'emploi de cette page
#
#
# Ce document (on appelle cela un Jupyter Notebook) est une alternance de cellules de texte, et de cellules de code Python. Elle permet d'exécuter du code en ligne sans se soucier de l'installation locale de son ordinateur, pour des séries de petits exercices.
#
# Cependant pour écrire des programmes plus complets on utilisera un editeur de code (exemple ***pyzo, VScode*** ), ce que nous verrons prochainement.
#
#
#
# On navigue entre les cellules avec les touches UP: ↑ et DOWN: ↓
#
# Les cellules identifiées par **Entrée**, contiennent du **code python** et il faut les **exécuter** pour voir le résultat.  Il y a plusieurs méthodes pour exécuter les cellules
#
#   - Au clavier **Majuscule+Entrée**  ou  **Ctrl+Entrée**.
#   - À la souris en cliquant dans la barre sur **▶Exécuter**.
#   - On doit constater qu'il y a un numéro qui apparaît (ou change),  par exemple  **Entree [1]:**
#
# L'ORDRE D'EXECUTION DES CELLULES A UN IMPACT !
#
# Les cellules identifiées avec une flèche à droite se déplient (indice, solution)
#
# ### Recommandations
#
#  - Lorsqu'il y a plusieurs lignes de programme, il est recommandé d'afficher les numéros de ligne (Menu Affichage/ Afficher/Masquer les numéros de ligne)
#
# - Pendant votre travail, pensez à <strong>sauvegarder régulièrement</strong> cliquant sur la disquette qui clignote, en haut à gauche.
#
# - Quand il y aura un problème n'hésitez pas de relancer le ***kernel***:  $\quad$   ***Noyau $\mapsto$ Redémarer & Effacer Les Sorties***
#
#
#
#
# <p style="text-align:justify;">On présente ici des exercices de bases du langage <strong>Python</strong>
#
# Note : vous pouvez également créer vous même des cellules en choisissant le menu Insérer une Cellule, et vous assurer qu'elle est indiquée en code pour du python, ou en Markdown pour prendre des notes en texte.
#
# !!!

# %% [markdown]
# !!! info 1 - QUELQUES BASES DE PYTHON - exercices calculs
# <span id="calculatrice" >
# !!!

# %% [markdown]
# !!! note 1.1 opérations
#
# Python permet d'effectuer tout type de calcul, comme une calculatrice ordinaire.
# !!!

# %%
5 + 8 #exécuter les cellules comme indiqué ci-dessus.

# %%
2-5

# %%
3/2

# %%
1+2*3

# %%
3*(5+2)

# %% [markdown]
# !!! note 1.2 Puissance
#
# Pour calculer une <strong>puissance</strong>, on utilise la notation ** .
#  </strong> Calculer le nombre $2^{12345}$ </div>
# !!!

# %%
#entrer votre code ci-dessous

# %% [markdown]
# Cela fait beaucoup de chiffres, 3717 très exactement. Python peut travailler avec de très grands nombres entiers.

# %% [markdown]
# !!! danger Le phénomène  suivant est vrai pour absolument tous les langages, mais il est bien souvent oublié.
# Quel est le résultat d'une opération simple telle que `0.7 + 0.1` ?
# !!!

# %%
0.7 + 0.1

# %% [markdown]
# On dirait qu'il y a un problème ... Cela provient de la représentation des nombres décimaux  (flottants) en machine :
# ils sont arrondis !  (On approfondira ceci dans le cours des flottants  - En Python, la solution consistera à utiliser un module spécial, le module <b>decimal</b>.)

# %% [markdown]
# !!! abstract Division
#
# Vous rappelez vous des **divisions euclidiennes** effectuées à l'école primaire?
#
# ```
# 7 | 4
# --|--
# 3 | 1
# ```
# - 7 est le **dividende**
# - 4 est est le **diviseur**
# - 1 est le **quotient**.
# - 3 est le **reste**.
# !!!

# %%
#opérateurs liés à la division
print(7/4)   #affiche le quotient de la division
print(7//4)  #affiche le quotient de la division euclidienne
print(7%4)   #affiche le reste de la division euclidienne (ou encore appelé modulo)

# %% [markdown]
#  !!! note 1.3 En utilisant les opérateurs précédents, écrire 437 secondes au format minutes:secondes.
# !!!

# %% [markdown]
# !!! info 2 - QUELQUES BASES DE PYTHON - Exercices variables
# !!!

# %% [markdown]
# !!! note 2.1 Affectations
# Créer une variable a qui contient la valeur 3.
#
# Lui ajouter 2
#
# La multiplier par 3
#
# L'afficher
# !!!

# %%
...
...
...
print(a)

# %% [markdown]
# !!! note  2.2 Affectations
# Refaire l'exercice avec les opérateurs += et *= et vérifier que les résultats sont identiques
# !!!

# %%
...
...
...
print(a)

# %% [markdown]
# !!! note  2.3 Affectations
# Exécuter les codes suivant : voilà d'autres manières de faire des affectations
# !!!

# %%
a = b = 3
print(a)
print(b)

# %%
c, d = 5, 12
print (c)
print(d)

# %% [markdown]
# !!! abstract Types
# !!!

# %%
#exécuter le code suivant
print(type(3))
print(type("3"))
print(type(3.0))

# %% [markdown]
# !!! note 2.4 Types
#
# Afficher le type des variables du code suivant en utilisant la fonction intégrée type()
#
# !!!

# %%
#exécuter et observez
bonjour = 8  
huit = "bonsoir"
bonsoir = bonjour
print("bonjour")  
print(bonjour)
print(huit)
print(bonsoir)

# %%
#votre code ici

# %% [markdown]
# !!! abstract un outil que nous allons souvent utiliser: la Méthode PRIMM
# Prédire (P)
#
# Exécuter (Run)
#
# Investiguer (I)
#
# Modifier (M)
#
# Faire vous même (Make)
#
# !!!

# %% [markdown]
# !!! note 2.5 utiliser la méthode PRIMM sur le code suivant :
#
#  P - Prédire le résultat,  R - puis exécuter le code,  I - puis investiguer le problème.
#  M - Modifier le code
#
# !!!

# %%
# écrire ici votre prédiction

# %%
#exécuter
var = Au revoir
print(var)

# %%
#code modifié fonctionnel

# %% [markdown]
# ??? tip indice
#
#   Corriger ci-dessus le code pour que l'exécution de la cellule affiche <code>Au revoir</code>
# ???

# %% [markdown]
# ??? success Solution
#
# Il n'y a pas les guillemets donc <code>Au revoir</code> devrait être une variable mais une variable ne peut pas contenir d'espace et donc python comprend qu'il y a deux variables, la variable <b> Au</b>  et la variable <b> revoir</b>.
# ???

# %% [markdown]
# !!! note 2.6 PRIMM :  M - Faire vous même
# Faire votre propre code sans la solution pour pour que l'exécution de la cellule ci-dessous affiche 8.
#
# !!!

# %%
#tester en executant
ma variable = 8
print(ma variable)

# %%
#votre code

# %% [markdown]
# !!! note <strong>2.7 : Échange de variables</strong>
#
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
# Stan Marsh  <img style="vertical-align:middle; display:inline;" alt='Stan_Marsh'  src='https://megamaths.hd.free.fr/static/seconde/Stan_Marsh.svg' width=30 />  aimerait avoir un algorithme permettant de permuter les nombres stockés dans deux variables a et b.
# Pour simplifier, on prendra 8 pour la variable a et -3 pour la variable b.
#
#
#
# 1. Kyle Broflovski  <img style="vertical-align:middle; display:inline;" alt='Kyle Broflovski'  src='https://megamaths.hd.free.fr/static/seconde/Kyle_Broflovski.svg' width=30 />   propose l'algorithme suivant :
#
# ```python
# a=8
# b=-3
#
# a=b
# b=a
# ```
#
# Est-ce le programme proposé par  Kyle Broflovski permet d'échanger les valeurs stockées dans les varables a et de b ?
# justifier.
#
# </div>
# !!!

# %%
#cellule pour tester

# %% [markdown]
# !!! note <strong>2.8 : Échange de variables - bis</strong>
#
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
#
# 2. Eric Cartman <img style="vertical-align:middle; display:inline;" alt='Eric Cartman'  width=30   src='https://megamaths.hd.free.fr/static/seconde/Eric_Cartman.svg' /> propose l'algorithme suivant :
#
# ```python
# a=8
# b=-3
#
# b=a
# a=b
# ```
#
# Est-ce le programme proposé par Eric Cartman permet d'échanger les valeurs stockées dans les variables a et de b ?
# justifier.
#
#
# </div>
# !!!

# %%
#cellule pour tester

# %% [markdown]
# !!! note <strong>2.9 : Échange de variables - ter</strong>
#
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
#
# 3. À vous <img style="vertical-align:middle; display:inline;" alt='Kenny McCormick'  width=30   src='https://megamaths.hd.free.fr/static/seconde/Kenny_McCormick.svg' />   de proposer un programme qui permet d'échanger les valeurs stockées dans les variables a et de b ?
#
#
#
# </div>
# !!!

# %%
#cellule pour tester

# %% [markdown]
# !!! info 3 - QUELQUES BASES DE PYTHON - Structure de tests
#
# !!!

# %% [markdown]
# !!! abstractLes structures de tests : SI - ALORS - SINON testent des CONDITIONS
# Les conditions sont des expressions qui renvoient une valeur de type booléen.
# !!!

# %% [markdown]
# !!! note 3.1 Opérateurs de comparaison
# Exécutez les codes suivants
# !!!

# %%
type(1 < 5)

# %%
1 < 5

# %%
1 > 5

# %%
1 == 5

# %%
1 != 5

# %% [markdown]
# !!! note 3.2 Opérateurs logiques and et or
# Pour combiner des conditions :
# Completer avec les deux opérateurs and et or et observez les résultats
# !!!

# %%
print(1 < 5  ... 2 <3) 
print(1 < 5  ... 2 <3)

# %%
print(5 < 7 ...  8 < 4)
print(5 < 7 ...  8 < 4)

# %%
print(5 < 4 ...  8 < 12)
print(5 < 4 ...  8 < 12)

# %% [markdown]
# !!! note 3.3 Structure de tests - plus grand
# Écrire un programme qui compare les variables a et b et affiche le plus grand des deux
# !!!

# %%
a = 8
b = 15
#votre code

# %%
#tester avec différentes valeurs de a et b

# %% [markdown]
# ??? success Solution
#
#
# ```python
# if a>b:
#     print(a)
# else:
#     print(b)
#
# ???

# %% [markdown]
# !!! note 3.4 Structure de tests - distance
# Écrire un programme qui calcule la **distance** séparant  deux bornes kilométriques b1 et b2.
# *Notez que le résultat doit être un nombre positif ou nul pour n'importe quelle combinaison de bornes.*
# !!!

# %%
b1, b2 = 325, 524
#votre code

# %%
#tester egalement avec b1, b2 = 815, 78

# %% [markdown]
# !!! note 3.5 Structure de tests - nombre pair
# Écrire un programme qui affiche True si le nombre n est pair ou False s'il est impair.
# !!!

# %%
n = 15
...

# %%
#tester egalement avec  n = 22

# %% [markdown]
# !!! note 3.6 Structure de tests - annee bissextile
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
#
# Une année est déclarée bissextile (et compte donc 366 jours au lieu de 365) si elle est :
# - soit divisible par 400.
# - soit divisible par 4 mais pas divisible par 100.
#
# Écrire un programme qui affiche **`True`** si une année est bissextile ou **`False`** si elle ne l'est pas.
#
# </div>
#
# *Explication : la Terre faisant le tour du Soleil en [un peu plus que 365 jours](https://fr.vikidia.org/wiki/R%C3%A9volution_de_la_Terre_autour_du_Soleil), on s'est dit qu'on allait rajouter un jour tous les 4 ans, mais c'était trop, alors on a enlevé un jour tous les 100 ans, mais c'était plus assez, alors on a rajouté un jour tous les 400 ans, ce qui donne une approximation convenable.*
#
# *Remarque: L'introduction du [calendrier grégorien](https://fr.wikipedia.org/wiki/Calendrier_gr%C3%A9gorien)  commença le vendredi 15 octobre 1582, qui fut le lendemain du jeudi 4 octobre 1582*
# !!!

# %%
annee = 2022  #doit afficher False
...

# %%
annee = 2024  #doit afficher True
...

# %% [markdown]
# !!! info 4 - QUELQUES BASES DE PYTHON - Fonctions et modules utiles
#
# !!!

# %% [markdown]
# !!! abstract Pour utiliser une fonction d'un module il faut commencer par l'importer.
# ```python
# import module
# ou
# from module import fonction
# ```
# !!!

# %%
import math #permet de charger le module mathématiques
print(math.pi)  # le nombre pi

# %% [markdown]
# La fonction `help()` permet d'avoir de l'aide sur un module ou une fonction

# %%
help(math)

# %%
#ou autrement
from math import sqrt #importe uniquement la fonction racine carrée
sqrt(49)

# %%
help(math.sqrt)

# %% [markdown]
# !!! note 4.1 Module math
# Afficher la somme des racines carrées de 2 à 4
#
# !!!

# %% [markdown]
# !!! note 4.2 Module random
# importer le module random et utiliser la fonction randint pour générer un nombre aléatoire entre  1 et 10
#
# !!!

# %%
# importation

# %%
#afficher l'aide

# %%
#utiliser la fonction randint etl'afficher (3 fois pour vérifier que cela change)

# %% [markdown]
# !!! note 4.3 utiliser randint dans les programmes de tests
# Reprendre vos programmes 3.3, 3.4, 3.5, 3.6 des structures de tests ci-dessus section 3 et remplacer les valeurs des variables par des valeurs aléatoires.
#
# !!!

# %%
#utiliser la fonction randint

# %%
#utiliser la fonction randint

# %%
#utiliser la fonction randint

# %% [markdown]
# !!! info 5 Quelques Compléments
#
# !!!

# %% [markdown]
# !!! note 5.1 fonction intégrée print()
# Proposer deux méthodes différentes pour afficher dans le code ci dessous le texte :
# Le contenu de la variable a est *valeur de a* .
#
# !!!

# %%
a = 'cinq'
print(...)
print(...)

# %% [markdown]
# !!! note 5.2 fonction intégrée print()
# Afficher le message ci-dessous avec des f-string  :
#
# Le produit de *valeur de a* par *valeur de b* vaut *valeur de a x b*
#
# !!!

# %%
a=4
b=5
print(...

# %% [markdown]
# !!! note 5.3 fonction intégrée input()
#
# écrire les instructions pour saisir le nom d'une personne à l'aide de input
# !!!

# %% [markdown]
# !!! note 5.4 fonction intégrée input()
#
# écrire les instructions pour saisir l'age d'une personne et afficher verifier si elle est majeure.
#
# Rappel : la fonction input renvoie un type str
# !!!

# %% [markdown]
# !!! note 5.5 chaines de caractères
#
# écrire l'instruction pour affecter dans la variable nom_complet la concaténation des noms et prénoms ci-dessous:
#
# !!!

# %%
nom = "Simpson"
prenom = "Marge"
...

# %% [markdown]
# !!! note 5.6 chaines de caractères - accès
#
# L'accès à un caractère particulier d'une chaîne se fait en indiquant sa position entre crochets.
#
# Le premier caractère est à la position 0.
# ```python
# mot = "Numérique"
# print (mot[0]) # affiche 'N'
# print (mot[3]) # affiche 'é'
# ```
# Compléter le code suivant pour extraire les initiales des mot suivants et les ranger dans une variable nommée initiales :
#
#
# !!!

# %%
mot1 = "Numérique"
mot2 = "Sciences"
mot3 = "Informatique"
initiales = ...

# %% [markdown]
# !!! note 5.7 chaines de caractères - musique de fin
#
# Qu'affiche le programme suivant ?
#
# !!!

# %%
note = "Ta"
musique_9eme = 5 * note
print(musique_9eme + "!")

# %% [markdown]
# !!! abstract  Annexe 1  - Typage dynamique
#
# Python réalise le typage dynamique des variables, c'est à dire qu'il devine le type lors d'une affectation.
#
# L'espace des variables s'appelle un espace de nommage, les données sont dans l'espace des objets (dans python tout est objet)
#
# Que se passe t il quand on écrit et valide la ligne suivante `a = 3` ?
# !!!

# %%
a=3

# %% [markdown]
# Python va réaliser 3 opérations :
#
# <table>
# <tr style="background-color:white;"><td style="text-align:left">1. Python crée l'entier 3 dans l'espace des objets. C'est un objet de type entier dont la valeur est 3. </td><td><img alt="objet" src="https://megamaths.hd.free.fr/static/seconde/objet1.svg"  width="200" /></td></tr>
# <tr style="background-color:white;"><td style="text-align:left">2. Python crée une variable a dans l'espace des variables </td><td><img alt="objet" src="https://megamaths.hd.free.fr/static/seconde/objet2.svg"  width="200"  style="display: inline-block;"/></td></tr>
# <tr style="background-color:white;"><td style="text-align:left">3. Python crée une référence entre la variable a et l'entier 3  </td><td><img alt="objet" src="https://megamaths.hd.free.fr/static/seconde/objet3.svg"  width="200"  style="display: inline-block;"/></td></tr>
#  </table>

# %% [markdown]
# Si on écrit (et valide) maintenant `a='nsi'`

# %%
a='nsi'

# %% [markdown]
# <table>
#     <tr style="background-color:white;"><td style="text-align:left">4. python <b>crée</b> de même un <b>objet</b> de type chaîne de caractères dont la valeur est nsi.</td><td><img alt="objet" src="https://megamaths.hd.free.fr/static/seconde//objet4.svg"  width="200"  /></td></tr>
# <tr style="background-color:white;"><td style="text-align:left">5. Il va créer une variable a mais la variable a existe déjà donc il va <b>déréférencer</b> la variable a.   </td><td><img alt="objet" src="https://megamaths.hd.free.fr/static/seconde/objet5.svg"  width="200" /></td></tr>
#     <tr style="background-color:white;"><td style="text-align:left">6. Python <b>crée une référence</b> entre la variable a et la chaîne 'nsi'  </td><td><img alt="objet" src="https://megamaths.hd.free.fr/static/seconde/objet6.svg"  width="200" /></td></tr>
#     <tr style="background-color:white;"><td style="text-align:left">7. On peut aussi supprimer la variable a avec <code>del a</code></td><td><img alt="objet" src="https://megamaths.hd.free.fr/static/seconde//objet7.svg"  width="200" /></td></tr>
#     </table>

# %%
del a

# %% [markdown]
# Cela veut dire qu'en python que le type n'est pas lié à la variable mais à l'objet.
#
# Si les objets n'ont plus de référence, il existe un mécanisme (garbage collector) qui va libérer la mémoire de l'ordinateur.
#
# On dit variable car les données qu'elle contient peuvent varier. Plus exactement c'est la référence qui change.
